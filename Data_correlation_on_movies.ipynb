# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# standerize the size of the plots
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.set_option('display.max_rows', None)

# read data
df = pd.read_csv(r'C:\Users\Jeffery\Desktop\Portfolio\Python_correlation\movies.csv')

# check if there is missing data
for col in df.columns:
    missing_percent = np.mean(df[col].isnull())
    print('{} column is missing {}%'.format(col, missing_percent))
# Out:
# name column is missing 0.0%
# rating column is missing 0.010041731872717789%
# genre column is missing 0.0%
# year column is missing 0.0%
# released column is missing 0.0002608242044861763%
# score column is missing 0.0003912363067292645%
# votes column is missing 0.0003912363067292645%
# director column is missing 0.0%
# writer column is missing 0.0003912363067292645%
# star column is missing 0.00013041210224308815%
# country column is missing 0.0003912363067292645%
# budget column is missing 0.2831246739697444%
# gross column is missing 0.02464788732394366%
# company column is missing 0.002217005738132499%
# runtime column is missing 0.0005216484089723526%

# %%
# delete the rows that contains NA
df = df.dropna()

# %%
# Drop any duplicates
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# removing the decimals in 'votes', 'budget', and 'gross'
df['votes'] = df['votes'].astype('int64')
df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
# add a new column with the corrected releaced year
df['yearcorrected'] = df['released'].str.extract(pat = '([0-9]{4})').astype('int')

# %%
df = df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score    votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
# scatter plot for budget vs gross
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earning')
plt.xlabel('Budget')
plt.ylabel('Gross Earning')
# Out:
# Text(0, 0.5, 'Gross Earning')

# %%
# plot Budget vs Gross in a regression plot
sns.regplot(x='budget', y='gross', data=df, line_kws={'color':'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# looking at correlation in the data
corr_matrix = df.corr(method='pearson')
corr_matrix
# Out:
#                    year     score     votes    budget     gross   runtime  \
# year           1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score          0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes          0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget         0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross          0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime        0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrected  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#                yearcorrected
# year                0.998726
# score               0.061923
# votes               0.203098
# budget              0.320312
# gross               0.268721
# runtime             0.075294
# yearcorrected       1.000000

# %%
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# looking at the colums that are not numeric
df_alter = df

for col in df_alter:
    if(df_alter[col].dtype == 'object'):
        df_alter[col] = df_alter[col].astype('category')
        df_alter[col] = df_alter[col].cat.codes
df_alter.head()
# Out:
#       name  rating  genre  year  released  score    votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000       785    1263
# 7445   388       5      0  2019       137    8.4   903000       105     513
# 3045  4909       5      6  1997       534    7.8  1100000       785    1263
# 6663  3643       5      0  2015       529    7.8   876000       768    1806
# 7244   389       5      0  2018       145    8.4   897000       105     513
#
#       star  country     budget       gross  company  runtime  yearcorrected
# 5445  1534       47  237000000  2847246203     1382    162.0           2009
# 7445  1470       47  356000000  2797501328      983    181.0           2019
# 3045  1073       47  200000000  2201647264     1382    194.0           1997
# 6663   356       47  245000000  2069521700      945    138.0           2015
# 7244  1470       47  321000000  2048359754      983    149.0           2018

# %%
corr_matrix_alter = df_alter.corr()
corr_matrix_alter
# Out:
#                    name    rating     genre      year  released     score  \
# name           1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating        -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre          0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year           0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released      -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score          0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes          0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director       0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer         0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star          -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country       -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget         0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# ...

# %%
sns.heatmap(corr_matrix_alter, annot=True)
plt.title('Correlation Matrix for Movies')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
corr_pair = corr_matrix_alter.unstack()
corr_pair.head()
# Out:
# name  name        1.000000
#       rating     -0.029234
#       genre       0.010996
#       year        0.025542
#       released   -0.006152
# dtype: float64

# %%
sorted_corr_pair = corr_pair.sort_values()
sorted_corr_pair.head()
# Out:
# genre   budget   -0.368523
# budget  genre    -0.368523
# gross   genre    -0.244101
# genre   gross    -0.244101
# rating  budget   -0.203946
# dtype: float64

# %%
high_corr = sorted_corr_pair[(sorted_corr_pair) > 0.5]
high_corr
# Out:
# gross          votes            0.614751
# votes          gross            0.614751
# gross          budget           0.740247
# budget         gross            0.740247
# year           yearcorrected    0.998726
# yearcorrected  year             0.998726
# name           name             1.000000
# company        company          1.000000
# gross          gross            1.000000
# budget         budget           1.000000
# country        country          1.000000
# star           star             1.000000
# writer         writer           1.000000
# director       director         1.000000
# votes          votes            1.000000
# score          score            1.000000
# released       released         1.000000
# year           year             1.000000
# genre          genre            1.000000
# rating         rating           1.000000
# runtime        runtime          1.000000
# yearcorrected  yearcorrected    1.000000
# dtype: float64

# %%
# In the end, we can see 'budget and gross' have the highest correlation and 'gross and votes' also have a high correlation.
